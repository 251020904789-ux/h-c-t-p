# %% [markdown]
# <a href="https://colab.research.google.com/github/251020904789-ux/h-c-t-p/blob/main/Ch%C3%A0o_m%E1%BB%ABng_b%E1%BA%A1n_%C4%91%E1%BA%BFn_v%E1%BB%9Bi_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input())
tong = 0
for i in range(2, n + 1, 2):
  tong += i
  print(tong)
# Out:
# 10
# 2
# 6
# 12
# 20
# 30

# %%
s = input().strip()
words = s.split()
print("words:",len(words))
longest = words[0]
for w in words:
  if len(w) > len(longest):
    longest = w
    print(longest)
# Out:
# lap trinh python co ban
# words: 5
# trinh
# python

# %%
nums = list(map(int, input().split()))
unique_nums = list(set(nums))
unique_nums.sort()
print("sorted list:", unique_nums)
second_largest = unique_nums[-2]
print("second largest:", second_largest)
# Out:
# 5 1 3 5 2 3
# sorted list: [1, 2, 3, 5]
# second largest: 3

# %%
  scores = list(map(int, input().split()))
  valid_scores = [s for s in scores if 0 <= s <= 10]
  average = sum(valid_scores) / len(valid_scores)
  passed = sum(1 for s in valid_scores if s >= 5)
  print("average:", average)
  print('passed:', passed)
# Out:
# 7 8 11 -1 4 5
# average: 6.0
# passed: 3
