# %% [markdown]
# <a href="https://colab.research.google.com/github/251020904789-ux/h-c-t-p/blob/main/Untitled7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = int(input("Enter a positive integer: "))

s = 0 # Biến số dùng để lưu tổng (variable to store the sum)
i = 0

while i < n:
    s += i
    i += 2

print(f"The sum of even numbers less than {n} is {s}")
# Out:
# Enter a positive integer: 14
# The sum of even numbers less than 14 is 42
