# %% [markdown]
# <a href="https://colab.research.google.com/github/251020904789-ux/h-c-t-p/blob/main/B%E1%BA%A3n_sao_c%E1%BB%A7a_untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
n = 14 # Gán trực tiếp giá trị 14 cho n
tong = 0
for i in range(n + 1):  # chạy từ 0 đến n
    tong += i
print("Tổng các số từ 0 đến", n, "là:", tong)
# Out:
# Tổng các số từ 0 đến 14 là: 105
